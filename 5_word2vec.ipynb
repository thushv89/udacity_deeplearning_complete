# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.230970
# Nearest to while: extensions, waitress, massless, brno, competences, unscathed, succumbed, zach,
# Nearest to are: overweight, distort, lawn, appending, contrastive, macarthur, diabetics, cfcs,
# Nearest to than: reiner, maximilian, manatees, loss, neuromancer, soles, forecast, migratory,
# Nearest to some: shipbuilding, vestiges, sorts, bostonians, intercepting, vein, mediate, finitely,
# Nearest to many: piled, gpled, appreciate, waste, hellish, atalanta, snowmen, transitioned,
# Nearest to will: arid, redemption, daffodils, catastrophes, sham, hydrochloride, openstep, mori,
# Nearest to s: nativity, rudd, mages, colloquialism, reelected, excel, proportional, lorne,
# Nearest to known: serial, reciprocating, battlefields, supernovae, denning, squaw, probation, quote,
# Nearest to have: bowell, jiangxi, pooled, hone, dunwich, castille, unsaturated, ifc,
# Nearest to may: isotopes, solver, exiting, wins, homosexuals, vaporized, temp, imperialism,
# Nearest to eight: shia, tooth, positing, wakefulness, nage, shreck, katal, partitive,
# Nearest to war: avercamp, enhancers, quelled, marinetti, knightly, remarkable, suppresses, randomization,
# Nearest to during: pynchon, marital, evict, opener, urged, irina, mandated, sentiments,
# Nearest to three: halmos, clintons, webpages, templar, allocation, vows, storybook, subtitled,
# Nearest to he: iterate, minefields, scraping, abernathy, african, drawings, heinz, loewe,
# Nearest to it: oligopoly, loretta, scientifically, middletown, p, koenig, prescribe, receivers,
# Average loss at step 2000: 4.371556
# Average loss at step 4000: 3.866762
# Average loss at step 6000: 3.789917
# Average loss at step 8000: 3.688702
# Average loss at step 10000: 3.618691
# Nearest to while: after, competences, extensions, unscathed, massless, drachma, magni, sumatran,
# Nearest to are: were, is, have, lans, be, ny, shandy, publicized,
# Nearest to than: manatees, or, reiner, neuromancer, loss, sdi, descendants, migratory,
# Nearest to some: many, several, most, rth, false, professional, all, dalek,
# Nearest to many: some, other, these, several, jaguars, all, waste, fruiting,
# Nearest to will: would, can, may, should, do, daffodils, parcels, recess,
# Nearest to s: his, cradle, staves, australopithecus, millsaps, its, neustadt, and,
# Nearest to known: cosby, monarchical, used, adjusts, reissues, mosques, scandinavian, must,
# Nearest to have: be, has, had, were, are, unsaturated, basins, bender,
# Nearest to may: can, would, will, gy, cruciform, denomination, patented, tastes,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to war: marinetti, affirmed, quelled, carriages, reaction, todd, knightly, avercamp,
# Nearest to during: in, pynchon, irina, of, urged, australian, lasker, junior,
# Nearest to three: eight, five, seven, two, four, six, zero, nine,
# Nearest to he: it, they, who, she, there, starved, possessors, rhythmically,
# Nearest to it: he, there, this, which, they, not, that, we,
# Average loss at step 12000: 3.604403
# Average loss at step 14000: 3.572800
# Average loss at step 16000: 3.411144
# Average loss at step 18000: 3.461879
# Average loss at step 20000: 3.540531
# Nearest to while: after, extensions, for, drachma, portuguese, competences, haskalah, but,
# Nearest to are: were, is, have, lans, faltered, tbilisi, velarized, was,
# Nearest to than: or, manatees, combustion, loss, reiner, neuromancer, clerihew, theocracy,
# Nearest to some: many, several, most, all, these, other, technicality, doubtful,
# Nearest to many: some, several, other, these, all, those, most, mare,
# Nearest to will: would, can, may, should, could, must, might, do,
# Nearest to s: francisco, matthias, climbed, xf, cultivating, angels, parodying, pacifist,
# Nearest to known: used, follows, such, cosby, adjusts, implant, mosques, fern,
# Nearest to have: had, has, be, are, were, unsaturated, spaceflight, basins,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to eight: six, nine, seven, four, five, three, two, one,
# Nearest to war: affirmed, marinetti, todd, feathered, glassy, synchronous, carriages, pieces,
# Nearest to during: in, pynchon, lasker, irina, australian, through, on, gael,
# Nearest to three: four, five, six, seven, two, eight, nine, one,
# Nearest to he: it, they, she, who, there, which, catalans, never,
# Nearest to it: he, there, this, they, which, not, often, she,
# Average loss at step 22000: 3.504381
# Average loss at step 24000: 3.495354
# Average loss at step 26000: 3.486102
# Average loss at step 28000: 3.481501
# Average loss at step 30000: 3.504867
# Nearest to while: after, although, for, were, extensions, haskalah, amyraut, but,
# Nearest to are: were, have, is, tbilisi, these, be, lans, include,
# Nearest to than: or, manatees, loss, descendants, convents, sdi, infinitives, trampled,
# Nearest to some: many, several, these, all, most, their, the, other,
# Nearest to many: some, several, these, those, all, other, most, the,
# Nearest to will: can, would, may, could, should, must, might, to,
# Nearest to s: his, matthias, climbed, neustadt, insane, her, millsaps, its,
# Nearest to known: used, such, follows, regarded, well, available, starcraft, cosby,
# Nearest to have: had, has, are, be, were, having, unsaturated, spaceflight,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to eight: seven, nine, four, six, five, three, zero, two,
# Nearest to war: marinetti, hats, affirmed, libertarian, generalized, randomization, carriages, neglect,
# Nearest to during: in, after, gael, through, on, under, lasker, irina,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to he: it, she, they, who, there, never, pictured, baku,
# Nearest to it: he, there, this, she, they, which, also, not,
# Average loss at step 32000: 3.504312
# Average loss at step 34000: 3.498544
# Average loss at step 36000: 3.454529
# Average loss at step 38000: 3.308129
# Average loss at step 40000: 3.422315
# Nearest to while: after, although, when, before, for, and, were, divisibility,
# Nearest to are: were, have, is, although, be, airfields, tbilisi, gainsborough,
# Nearest to than: or, manatees, loss, sdi, calculating, clerihew, convents, much,
# Nearest to some: many, several, these, those, any, most, doubtful, all,
# Nearest to many: several, some, these, those, most, both, various, their,
# Nearest to will: can, would, may, could, should, must, might, cannot,
# Nearest to s: his, surgically, matthias, tau, her, vives, bangs, courtship,
# Nearest to known: used, such, regarded, available, follows, starcraft, described, well,
# Nearest to have: had, has, were, be, are, bender, unsaturated, having,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to war: hats, marinetti, reaction, experience, affirmed, antioch, todd, repealing,
# Nearest to during: after, under, in, gael, on, chilling, lasker, since,
# Nearest to three: four, two, five, six, seven, eight, nine, mutilation,
# Nearest to he: she, it, they, who, there, never, starved, baku,
# Nearest to it: he, there, this, they, she, which, not, what,
# Average loss at step 42000: 3.433985
# Average loss at step 44000: 3.448474
# Average loss at step 46000: 3.455142
# Average loss at step 48000: 3.350856
# Average loss at step 50000: 3.382046
# Nearest to while: when, although, after, before, however, where, but, for,
# Nearest to are: were, have, is, although, these, lans, airfields, include,
# Nearest to than: or, much, loss, calculating, manatees, and, even, kinds,
# Nearest to some: many, several, these, all, both, those, various, most,
# Nearest to many: some, several, these, those, both, most, various, few,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to s: his, whose, and, climbed, xf, matthias, vives, has,
# Nearest to known: used, such, regarded, described, available, well, follows, starcraft,
# Nearest to have: had, has, were, are, be, rel, despair, having,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Nearest to eight: six, seven, nine, four, five, three, one, zero,
# Nearest to war: marinetti, champions, repealing, hats, col, antioch, affirmed, auras,
# Nearest to during: after, in, under, when, since, lasker, gael, through,
# Nearest to three: four, six, two, seven, eight, five, nine, zero,
# Nearest to he: she, it, they, who, there, starved, soon, never,
# Nearest to it: he, there, she, this, they, still, often, what,
# Average loss at step 52000: 3.437725
# Average loss at step 54000: 3.425706
# Average loss at step 56000: 3.436052
# Average loss at step 58000: 3.401467
# Average loss at step 60000: 3.393644
# Nearest to while: although, when, before, after, though, were, including, however,
# Nearest to are: were, is, have, lans, include, be, kepler, those,
# Nearest to than: and, or, much, loss, leftrightarrow, manatees, but, poaching,
# Nearest to some: many, several, these, most, all, both, different, this,
# Nearest to many: some, several, these, various, most, those, both, all,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to s: surgically, matthias, lo, corte, omen, surviving, whose, xf,
# Nearest to known: used, such, regarded, available, described, well, follows, starcraft,
# Nearest to have: had, has, are, were, be, include, having, spaceflight,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to eight: six, seven, nine, four, five, three, zero, one,
# Nearest to war: marinetti, twitch, glassy, champions, trenches, affricate, abundantly, grammatik,
# Nearest to during: after, in, under, following, since, before, although, when,
# Nearest to three: five, four, six, two, seven, eight, nine, one,
# Nearest to he: she, it, they, who, there, swordsmanship, never, starved,
# Nearest to it: he, there, she, this, what, which, they, that,
# Average loss at step 62000: 3.237684
# Average loss at step 64000: 3.257483
# Average loss at step 66000: 3.402136
# Average loss at step 68000: 3.398793
# Average loss at step 70000: 3.362397
# Nearest to while: although, before, however, after, when, including, and, though,
# Nearest to are: were, have, is, include, these, be, vue, although,
# Nearest to than: and, or, much, manatees, sdi, while, adl, but,
# Nearest to some: many, several, these, all, most, various, both, those,
# Nearest to many: some, several, various, these, all, most, those, numerous,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to s: surgically, whose, matthias, allomorphy, azad, hatcher, tycho, corte,
# Nearest to known: used, regarded, such, described, follows, available, well, starcraft,
# Nearest to have: had, has, were, include, are, be, having, rel,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to eight: nine, six, seven, four, five, zero, three, one,
# Nearest to war: glassy, marinetti, arab, twitch, champions, trenches, indoctrination, affricate,
# Nearest to during: after, before, since, in, under, through, until, gael,
# Nearest to three: four, six, two, five, seven, eight, nine, one,
# Nearest to he: she, it, they, there, who, never, we, starved,
# Nearest to it: he, there, she, this, they, still, which, what,
# Average loss at step 72000: 3.371192
# Average loss at step 74000: 3.348944
# Average loss at step 76000: 3.317606
# Average loss at step 78000: 3.351593
# Average loss at step 80000: 3.376254
# Nearest to while: although, after, condor, however, before, though, when, but,
# Nearest to are: were, is, include, have, although, including, vegetarian, burton,
# Nearest to than: or, much, mantled, far, manatees, and, groove, unn,
# Nearest to some: many, several, most, these, all, various, both, numerous,
# Nearest to many: several, some, various, these, most, numerous, those, both,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to s: surgically, whose, lo, quin, pennants, intergovernmental, matthias, vives,
# Nearest to known: used, described, regarded, available, called, follows, such, starcraft,
# Nearest to have: had, has, be, are, having, were, include, rel,
# Nearest to may: can, would, could, must, might, will, should, cannot,
# Nearest to eight: six, nine, five, seven, four, three, zero, two,
# Nearest to war: marinetti, twitch, wars, glassy, factbook, trenches, arab, cup,
# Nearest to during: after, in, before, when, despite, since, through, although,
# Nearest to three: six, five, four, seven, eight, two, nine, zero,
# Nearest to he: she, it, they, there, who, never, soon, we,
# Nearest to it: he, there, she, this, they, we, possessors, not,
# Average loss at step 82000: 3.409504
# Average loss at step 84000: 3.412302
# Average loss at step 86000: 3.385644
# Average loss at step 88000: 3.358780
# Average loss at step 90000: 3.363504
# Nearest to while: although, when, after, before, though, were, but, during,
# Nearest to are: were, is, include, have, although, these, vegetarian, contain,
# Nearest to than: or, much, mantled, leftrightarrow, australasia, groove, far, immanence,
# Nearest to some: many, several, these, most, all, both, any, those,
# Nearest to many: several, some, numerous, various, these, few, most, those,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to s: whose, his, corte, matthias, vives, your, surviving, quin,
# Nearest to known: used, regarded, described, such, available, called, possible, seen,
# Nearest to have: had, has, were, having, are, be, rel, include,
# Nearest to may: can, could, might, would, must, should, will, cannot,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to war: during, wars, glassy, twitch, bust, champions, affricate, fighting,
# Nearest to during: in, after, before, when, despite, until, while, since,
# Nearest to three: four, five, two, six, seven, eight, nine, one,
# Nearest to he: she, it, they, there, who, never, we, later,
# Nearest to it: he, she, there, this, they, often, never, possessors,
# Average loss at step 92000: 3.396847
# Average loss at step 94000: 3.254604
# Average loss at step 96000: 3.364785
# Average loss at step 98000: 3.244403
# Average loss at step 100000: 3.357749
# Nearest to while: although, when, though, before, after, and, but, however,
# Nearest to are: were, have, include, these, although, be, is, while,
# Nearest to than: or, mantled, and, but, leftrightarrow, australasia, groove, much,
# Nearest to some: many, several, these, any, most, numerous, their, those,
# Nearest to many: several, some, various, these, numerous, few, those, all,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to s: whose, his, starring, surgically, quin, isbn, consonantal, matthias,
# Nearest to known: such, regarded, used, described, possible, available, seen, starcraft,
# Nearest to have: had, has, include, were, are, having, be, tend,
# Nearest to may: can, could, must, might, should, would, will, cannot,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to war: wars, champions, trenches, twitch, rearrangement, glassy, seds, marinetti,
# Nearest to during: after, in, before, when, until, despite, within, through,
# Nearest to three: four, five, six, two, seven, eight, nine, one,
# Nearest to he: she, it, they, there, who, never, we, starved,
# Nearest to it: he, she, this, there, they, what, never, which,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
