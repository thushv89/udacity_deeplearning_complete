# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# ## Downloading Data

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# ## Converting data to a string

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# ## Building the Vocabulary (Dictionaries)

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# ## Generating batches of data
#
# Unlike data in skip-gram, here data is of following sizes
# * batch: [batch_size, context_window size - 1] # words found in the context
# * labels: [batch_size, 1] # target word (word to be predicted)

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side

    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        # do this num_skips (2 times)
        # do this (1 time)

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels



for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# ## Running Embedding Learning

# %%
num_steps = 100001

if __name__ == '__main__':
    batch_size = 128
    embedding_size = 128 # Dimension of the embedding vector.
    skip_window = 1 # How many words to consider left and right.
    num_skips = 2 # How many times to reuse an input to generate a label.
    # We pick a random validation set to sample nearest neighbors. here we limit the
    # validation samples to the words that have a low numeric ID, which by
    # construction are also the most frequent.
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100 # Only pick dev samples in the head of the distribution.
    # pick 16 samples from 100
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
    num_sampled = 64 # Number of negative examples to sample.

    graph = tf.Graph()

    with graph.as_default(), tf.device('/cpu:0'):

        # Input data.
        train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

        # Variables.
        # embedding, vector for each word in the vocabulary
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Averaging embeddings accross the full context into a single embedding layer
        context_embeddings = []
        for i in range(2*skip_window):
            context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            
        avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)

        # Compute the softmax loss, using a sample of the negative labels each time.
        # inputs are embeddings of the train words
        # with this loss we optimize weights, biases, embeddings

        loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

        # Optimizer.
        optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

        # Compute the similarity between minibatch examples and all embeddings.
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print('Initialized')
        average_loss = 0
        for step in range(num_steps):
            batch_data, batch_labels = generate_batch(batch_size, skip_window)
            feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
            _, l = session.run([optimizer, loss], feed_dict=feed_dict)
            average_loss += l
            if step % 2000 == 0:
                if step > 0:
                    average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# [2, 128, 128]
# Initialized
# Average loss at step 0: 5.710615
# Nearest to years: forthcoming, volt, kinky, cosgrave, prowess, erodes, extravagance, donovan,
# Nearest to by: bashir, lastly, pranksters, pople, microchip, gibeon, laura, oswego,
# Nearest to to: game, masterminded, texaco, pura, shame, mus, sacerdotal, chagrin,
# Nearest to new: kludge, defending, midnight, attempts, brotherhood, peacetime, sisyphus, balinese,
# Nearest to there: loon, outs, shredded, lipids, amraam, guises, canada, orientalis,
# Nearest to been: lima, sino, geometry, scaffold, triumphant, sandalwood, yehoshua, yorke,
# Nearest to b: rearguard, rationalists, algerian, stronger, ananda, norfolk, goldsmiths, splice,
# Nearest to however: nomenclature, oncology, actuated, albuquerque, kazakhs, farthest, nuggets, amended,
# Nearest to marriage: dubliners, betraying, idaho, glencoe, hemorrhage, lar, exorcist, cultured,
# Nearest to units: kurosawa, daimler, ncp, said, dwan, amphibians, hasidism, walks,
# Nearest to instance: slapped, gascony, fairgrounds, succeeds, tending, arbitrage, lakeland, kazan,
# Nearest to orthodox: banco, cemetery, fiberglass, greet, comedy, wushu, bromide, inadequately,
# Nearest to additional: herero, iles, ashley, rey, prosecuting, finno, mcpherson, stops,
# Nearest to recorded: teos, munitions, croft, reorganised, fibrous, warmblood, telecommunications, shearer,
# Nearest to event: pastiches, bertie, geosynchronous, franciscan, coleman, friendliness, flight, disorder,
# Nearest to troops: psalm, purposes, exceptional, alces, shankar, fascist, reunion, seizing,
# Average loss at step 2000: 4.004910
# Average loss at step 4000: 3.514837
# Average loss at step 6000: 3.205194
# Average loss at step 8000: 3.279488
# Average loss at step 10000: 3.205022
# Nearest to years: donovan, forthcoming, ambivalent, milton, erodes, kenjutsu, qing, ao,
# Nearest to by: pranksters, midair, from, under, scytale, aford, pinocchio, into,
# Nearest to to: would, ballerina, game, could, sacerdotal, deutschen, flintstones, laos,
# Nearest to new: second, flaw, imbalance, kludge, prepaid, sexist, brotherhood, attempts,
# Nearest to there: they, lipids, still, ying, now, often, it, incas,
# Nearest to been: downfall, lima, become, triumphant, scaffold, lifeless, dewitt, bihari,
# Nearest to b: d, repetitions, rearguard, rgen, wade, foreword, revamp, medieval,
# Nearest to however: nuggets, truetype, objectivist, afterward, but, albuquerque, codify, cenozoic,
# Nearest to marriage: betraying, dubliners, idaho, glencoe, lar, exorcist, affection, speeds,
# Nearest to units: kurosawa, daimler, ncp, private, dwan, hasidism, amphibians, schizophrenia,
# Nearest to instance: gascony, succeeds, fairgrounds, estimation, tending, hortense, arbitrage, contented,
# Nearest to orthodox: cemetery, wushu, banco, comedy, greet, fiberglass, rents, aia,
# Nearest to additional: herero, iles, counterfeiting, finno, ashley, stops, social, rey,
# Nearest to recorded: teos, munitions, reorganised, shearer, communal, miniaturized, warmblood, basingstoke,
# Nearest to event: pastiches, bertie, geosynchronous, friendliness, chatting, progresses, franciscan, snowball,
# Nearest to troops: purposes, shankar, exceptional, fascist, psalm, alces, seizing, gap,
# Average loss at step 12000: 3.173350
# Average loss at step 14000: 3.183384
# Average loss at step 16000: 3.098226
# Average loss at step 18000: 3.077008
# Average loss at step 20000: 3.070963
# Nearest to years: donovan, milton, forthcoming, months, ambivalent, persons, karenina, qing,
# Nearest to by: midair, pranksters, scytale, overviews, maharashtri, reconstructions, arousing, pinocchio,
# Nearest to to: would, will, could, nico, ballerina, flintstones, minuet, seller,
# Nearest to new: second, flaw, imbalance, maharal, northern, prepaid, rope, suborder,
# Nearest to there: they, still, lipids, she, ying, it, jannaeus, now,
# Nearest to been: become, be, lima, downfall, were, maids, sheppard, was,
# Nearest to b: d, repetitions, rearguard, pianist, rgen, revamp, wade, abnormality,
# Nearest to however: but, nuggets, stealthy, truetype, foibles, cenozoic, topologically, objectivist,
# Nearest to marriage: betraying, dubliners, idaho, glencoe, speeds, exorcist, lar, affection,
# Nearest to units: kurosawa, private, ncp, manifestation, dwan, hasidism, daimler, azo,
# Nearest to instance: estimation, example, succeeds, tending, syllables, butyl, fairgrounds, creations,
# Nearest to orthodox: wushu, cemetery, banco, comedy, rents, aia, introductions, polypeptide,
# Nearest to additional: herero, counterfeiting, iles, stops, social, ashley, finno, maoists,
# Nearest to recorded: munitions, teos, communal, reorganised, po, basingstoke, feet, shearer,
# Nearest to event: pastiches, friendliness, geosynchronous, comnenus, progresses, worlds, bertie, favoring,
# Nearest to troops: purposes, exceptional, snowstorm, cinematographer, shankar, contemporaries, ellery, fascist,
# Average loss at step 22000: 3.022503
# Average loss at step 24000: 3.036571
# Average loss at step 26000: 3.042907
# Average loss at step 28000: 2.990605
# Average loss at step 30000: 2.835914
# Nearest to years: months, days, ambivalent, forthcoming, milton, times, qing, karenina,
# Nearest to by: pranksters, bomis, maharashtri, gibeon, overviews, pinocchio, google, deliriants,
# Nearest to to: flintstones, will, sacerdotal, would, laos, nico, could, whale,
# Nearest to new: second, heritage, maharal, ta, imbalance, callaghan, suborder, flaw,
# Nearest to there: they, still, it, lipids, she, jannaeus, now, typically,
# Nearest to been: become, be, were, was, lima, maids, sheppard, fat,
# Nearest to b: d, r, repetitions, abnormality, pianist, g, elizabeth, svg,
# Nearest to however: but, that, nuggets, topologically, stealthy, while, softening, skid,
# Nearest to marriage: betraying, dubliners, idaho, speeds, glencoe, exorcist, affection, lar,
# Nearest to units: kurosawa, private, ncp, dwan, manifestation, hasidism, amphibians, atomism,
# Nearest to instance: example, estimation, reasons, butyl, need, gillies, syllables, succeeds,
# Nearest to orthodox: wushu, cemetery, rents, aia, jewish, catholic, banco, comedy,
# Nearest to additional: counterfeiting, herero, iles, stops, allowing, maoists, reconciling, social,
# Nearest to recorded: munitions, released, teos, communal, bax, feet, po, reorganised,
# Nearest to event: pastiches, comnenus, friendliness, mole, depletion, dimensions, excused, plagiarized,
# Nearest to troops: cinematographer, contemporaries, purposes, eraser, fascist, duplicate, snowstorm, grub,
# Average loss at step 32000: 2.983297
# Average loss at step 34000: 2.956051
# Average loss at step 36000: 2.941066
# Average loss at step 38000: 2.944703
# Average loss at step 40000: 2.980337
# Nearest to years: days, months, ambivalent, times, weeks, milton, karenina, forthcoming,
# Nearest to by: pranksters, gibeon, when, doping, arousing, blanche, aford, bomis,
# Nearest to to: will, would, should, could, can, might, must, towards,
# Nearest to new: second, suborder, callaghan, lukewarm, old, ufo, kludge, heritage,
# Nearest to there: they, it, still, he, she, afforded, lipids, jannaeus,
# Nearest to been: become, be, were, maids, lima, was, sheppard, already,
# Nearest to b: d, z, r, incubus, pianist, feelings, repetitions, lieder,
# Nearest to however: but, that, while, although, stealthy, except, seemingly, topologically,
# Nearest to marriage: betraying, dubliners, idaho, speeds, affection, glencoe, nul, exorcist,
# Nearest to units: kurosawa, private, dwan, ncp, bags, niue, ewell, states,
# Nearest to instance: example, estimation, need, reasons, except, responsible, useful, butyl,
# Nearest to orthodox: wushu, cemetery, catholic, jewish, rents, aia, alus, polypeptide,
# Nearest to additional: counterfeiting, herero, iles, stops, allowing, andover, observational, contradicting,
# Nearest to recorded: released, munitions, teos, communal, bax, basingstoke, feet, evolved,
# Nearest to event: pastiches, comnenus, case, webcams, mole, depletion, annotated, favoring,
# Nearest to troops: cinematographer, contemporaries, purposes, eraser, fascist, grub, snowstorm, duplicate,
# Average loss at step 42000: 2.929890
# Average loss at step 44000: 2.933795
# Average loss at step 46000: 2.853581
# Average loss at step 48000: 2.871021
# Average loss at step 50000: 2.885702
# Nearest to years: months, days, weeks, times, ambivalent, year, centuries, milton,
# Nearest to by: pranksters, when, maharashtri, nat, newly, pinocchio, during, fokker,
# Nearest to to: could, should, will, towards, flintstones, cannot, ballerina, sacerdotal,
# Nearest to new: maharal, flaw, callaghan, lump, suborder, lukewarm, attempts, defending,
# Nearest to there: they, it, she, he, still, afforded, jannaeus, wmo,
# Nearest to been: become, be, maids, was, were, lima, already, kilometer,
# Nearest to b: d, wade, moderne, pianist, rgen, ethan, murky, disregard,
# Nearest to however: but, that, although, while, stealthy, pests, berkshire, especially,
# Nearest to marriage: betraying, dubliners, speeds, idaho, nul, lar, affection, exorcist,
# Nearest to units: kurosawa, parts, ncp, niue, galen, private, ewell, lamps,
# Nearest to instance: example, except, need, estimation, reasons, responsible, useful, butyl,
# Nearest to orthodox: catholic, wushu, jewish, cemetery, rents, aia, alus, christians,
# Nearest to additional: herero, counterfeiting, iles, allowing, stops, andover, observational, contradicting,
# Nearest to recorded: released, munitions, teos, bax, communal, baryons, regarded, evolved,
# Nearest to event: comnenus, case, pastiches, mole, chatting, depletion, annotated, favoring,
# Nearest to troops: cinematographer, contemporaries, eraser, purposes, fascist, snowstorm, grub, nobility,
# Average loss at step 52000: 2.896290
# Average loss at step 54000: 2.759702
# Average loss at step 56000: 2.836689
# Average loss at step 58000: 2.868639
# Average loss at step 60000: 2.824845
# Nearest to years: days, months, weeks, times, centuries, decades, year, minutes,
# Nearest to by: through, pranksters, pinocchio, maharashtri, newly, during, arabians, doping,
# Nearest to to: sacerdotal, nico, should, flintstones, towards, laos, could, will,
# Nearest to new: flaw, suborder, lump, lukewarm, callaghan, monorail, maharal, old,
# Nearest to there: they, it, she, he, still, wmo, safin, these,
# Nearest to been: become, be, were, was, maids, already, lima, dewitt,
# Nearest to b: d, repetitions, murky, p, rgen, pianist, incubus, z,
# Nearest to however: but, although, that, while, kwh, especially, and, though,
# Nearest to marriage: betraying, nul, dubliners, lar, idaho, speeds, affection, exorcist,
# Nearest to units: kurosawa, parts, ncp, ewell, niue, lamps, dwan, taxes,
# Nearest to instance: example, except, need, reasons, responsible, estimation, useful, basis,
# Nearest to orthodox: jewish, catholic, wushu, cemetery, christians, aia, rents, polypeptide,
# Nearest to additional: herero, counterfeiting, allowing, observational, andover, stops, iles, contradicting,
# Nearest to recorded: released, munitions, bax, teos, regarded, baryons, uua, communal,
# Nearest to event: case, comnenus, pastiches, mole, telstra, webcams, definition, chatting,
# Nearest to troops: cinematographer, contemporaries, eraser, nobility, rule, forces, philosophers, monopolies,
# Average loss at step 62000: 2.736454
# Average loss at step 64000: 2.761759
# Average loss at step 66000: 2.794493
# Average loss at step 68000: 2.784132
# Average loss at step 70000: 2.789490
# Nearest to years: days, months, weeks, centuries, decades, times, year, minutes,
# Nearest to by: newly, fokker, pranksters, maharashtri, through, during, pinocchio, when,
# Nearest to to: towards, could, cannot, will, nico, minuet, should, would,
# Nearest to new: flaw, lump, suborder, monorail, lukewarm, defending, callaghan, nato,
# Nearest to there: they, it, she, he, afforded, wmo, we, still,
# Nearest to been: become, be, were, was, maids, lima, kilometer, heft,
# Nearest to b: d, pianist, repetitions, rgen, wade, murky, ssang, mcfadden,
# Nearest to however: but, although, while, that, though, kwh, especially, indeed,
# Nearest to marriage: nul, work, dubliners, lar, betraying, idaho, foobar, speeds,
# Nearest to units: kurosawa, companies, parts, taxes, biochemist, galen, dwan, lamps,
# Nearest to instance: example, except, need, reasons, estimation, responsible, basis, useful,
# Nearest to orthodox: catholic, jewish, wushu, cemetery, christians, aia, rents, ctus,
# Nearest to additional: herero, counterfeiting, allowing, contradicting, observational, andover, alternate, iles,
# Nearest to recorded: released, bax, munitions, baryons, teos, published, feet, uua,
# Nearest to event: case, comnenus, pastiches, mole, order, chatting, telstra, definition,
# Nearest to troops: cinematographer, rule, forces, nobility, contemporaries, philosophers, monopolies, eraser,
# Average loss at step 72000: 2.687962
# Average loss at step 74000: 2.814745
# Average loss at step 76000: 2.822576
# Average loss at step 78000: 2.715725
# Average loss at step 80000: 2.759664
# Nearest to years: days, months, weeks, decades, centuries, minutes, year, times,
# Nearest to by: newly, during, doping, maharashtri, when, from, fokker, pinocchio,
# Nearest to to: towards, could, should, nico, flintstones, overtraining, sacerdotal, shall,
# Nearest to new: flaw, lump, old, maharal, jiva, monorail, lukewarm, coaches,
# Nearest to there: they, it, she, he, wmo, safin, these, afforded,
# Nearest to been: become, be, was, were, maids, already, dewitt, heft,
# Nearest to b: d, pianist, murky, p, repetitions, ssang, rgen, foreword,
# Nearest to however: but, although, though, while, that, and, especially, gp,
# Nearest to marriage: nul, lar, dubliners, betraying, foobar, imac, delved, idaho,
# Nearest to units: companies, kurosawa, taxes, defence, biochemist, galen, lamps, dwan,
# Nearest to instance: example, except, need, reasons, estimation, responsible, basis, useful,
# Nearest to orthodox: catholic, jewish, wushu, cemetery, christians, aia, rents, protestant,
# Nearest to additional: counterfeiting, herero, contradicting, alternate, andover, observational, further, allowing,
# Nearest to recorded: released, bax, teos, published, munitions, baryons, bolstering, described,
# Nearest to event: case, comnenus, mole, pastiches, order, chatting, situation, dimensions,
# Nearest to troops: forces, cinematographer, rule, nobility, philosophers, soldiers, monopolies, queues,
# Average loss at step 82000: 2.745189
# Average loss at step 84000: 2.755485
# Average loss at step 86000: 2.774708
# Average loss at step 88000: 2.680696
# Average loss at step 90000: 2.776956
# Nearest to years: days, months, weeks, decades, centuries, minutes, year, times,
# Nearest to by: through, newly, pranksters, fokker, when, gibeon, blanche, maharashtri,
# Nearest to to: towards, should, shall, could, flintstones, must, would, might,
# Nearest to new: lump, flaw, maharal, monorail, defending, funneled, old, lukewarm,
# Nearest to there: they, it, she, he, we, afforded, still, these,
# Nearest to been: become, be, were, was, maids, already, nme, heft,
# Nearest to b: d, pianist, murky, rgen, p, c, z, alarc,
# Nearest to however: but, although, though, especially, that, indeed, while, today,
# Nearest to marriage: nul, lar, foobar, resale, imac, delved, betraying, affection,
# Nearest to units: taxes, companies, kurosawa, lamps, niue, galen, defence, biochemist,
# Nearest to instance: example, except, need, reasons, basis, estimation, responsible, necessary,
# Nearest to orthodox: catholic, wushu, jewish, christians, cemetery, aia, traditional, ctus,
# Nearest to additional: alternate, counterfeiting, herero, contradicting, observational, andover, allowing, extra,
# Nearest to recorded: released, published, bax, munitions, bolstering, teos, uua, baryons,
# Nearest to event: case, events, comnenus, situation, pastiches, mole, issue, exception,
# Nearest to troops: forces, rule, nobility, cinematographer, soldiers, army, philosophers, territory,
# Average loss at step 92000: 2.720796
# Average loss at step 94000: 2.690898
# Average loss at step 96000: 2.279259
# Average loss at step 98000: 2.494320
# Average loss at step 100000: 2.647649
# Nearest to years: days, months, weeks, decades, centuries, minutes, year, hours,
# Nearest to by: through, newly, amidah, with, microsite, enlists, against, under,
# Nearest to to: towards, should, would, shall, must, cannot, might, could,
# Nearest to new: old, maharal, flaw, monorail, truce, lump, robb, peacetime,
# Nearest to there: they, it, she, he, still, we, afforded, safin,
# Nearest to been: become, be, was, were, maids, already, crossover, heft,
# Nearest to b: d, wade, pianist, sz, rgen, lob, mexican, ethan,
# Nearest to however: but, although, though, while, that, indeed, especially, disciplined,
# Nearest to marriage: nul, lar, wife, foobar, imac, idaho, betraying, delved,
# Nearest to units: companies, taxes, kurosawa, galen, pupils, lamps, forces, composers,
# Nearest to instance: example, except, need, reasons, basis, estimation, responsible, necessary,
# Nearest to orthodox: catholic, wushu, jewish, christians, cemetery, jews, traditional, aia,
# Nearest to additional: alternate, herero, contradicting, observational, further, counterfeiting, extra, monkees,
# Nearest to recorded: released, published, described, discarded, bolstering, uua, regarded, munitions,
# Nearest to event: case, comnenus, events, situation, exception, mole, issue, principle,
# Nearest to troops: forces, soldiers, rule, cinematographer, nobility, army, philosophers, navy,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
